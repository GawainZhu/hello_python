# %% [markdown]
# <a href="https://colab.research.google.com/github/GawainZhu/hello_python/blob/main/chapter2_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#初始化环境
# !pip3 install ColabTurtle
import ColabTurtle.Turtle
td = ColabTurtle.Turtle

# %%
'''
将画笔设置为红色，并画个正方形
'''
