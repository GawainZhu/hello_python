# %% [markdown]
# <a href="https://colab.research.google.com/github/GawainZhu/hello_python/blob/main/chapter3_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **练习1**　用“*”号画出如图3-9所示的心。
#
# ![image.png](data:image/png;base64,...)

# %%
# 在这里写你的代码

# %% [markdown]
# **练习2**　按以下排版方式，输出古诗。
#
# ![image.png](data:image/png;base64,...)

# %%
# 在这里写你的代码
