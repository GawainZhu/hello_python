# %% [markdown]
# <a href="https://colab.research.google.com/github/GawainZhu/hello_python/blob/main/chapter2_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **练习1　请在IDLE内输入以下程序，并查看运行结果。**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **练习2　请在IDLE内输入以下程序，并查看运行结果。**
#
# ![image.png](data:image/png;base64,...)
