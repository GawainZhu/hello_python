# %% [markdown]
# <a href="https://colab.research.google.com/github/GawainZhu/hello_python/blob/main/chapter3_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 用print语句输出“Hello World”

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 用"#"号打印一个长方形
